# %% [markdown]
# # **Inserting node at particular Position**

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None

node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)
node5 = Node(50)
node6 = Node(60)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5
node5.next = node6

head = node1
current = head

while True:
  print("\n1.Display \n2.Insert a node at specific end \n3.exit")
  choice = int(input("Enter your choice:"))

  if choice == 1:
    current = head
    while current is not None:
      print(current.data,end = "->")
      current = current.next
    print("None")

  elif choice == 2:
    current = head
    position = int(input("\nafter which data you wanna insert the element"))
    value = int(input("enter your value"))

    new_node = Node(value)
    while current is not None and current.data != position:
      current = current.next
    new_node.next = current.next
    current.next = new_node

  elif choice == 3:
    print("Exiting the program....")
    break

  else:
    print("invalid choice!!! Enter the choice between (1-3)")
# Out:
# 1.Display
# 2.Insert a node at specific end
# 3.exit
# Enter your choice:1
# 10->20->30->40->50->60->None
#
# 1.Display
# 2.Insert a node at specific end
# 3.exit
# Enter your choice:2
#
# after which data you wanna insert the element30
# enter your value100
#
# 1.Display
# 2.Insert a node at specific end
# 3.exit
# Enter your choice:1
# 10->20->30->100->40->50->60->None
#
# 1.Display
# 2.Insert a node at specific end
# 3.exit
# Enter your choice:3
# Exiting the program....
